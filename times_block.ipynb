# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('times_block.csv')

# %%
data.head()
# Out:
#          Date  Usage  Notifications  Times opened        App
# 0  08/26/2022     38             70            49  Instagram
# 1  08/27/2022     39             43            48  Instagram
# 2  08/28/2022     64            231            55  Instagram
# 3  08/29/2022     14             35            23  Instagram
# 4  08/30/2022      3             19             5  Instagram

# %%
time_data = data['Date']

# %%
time_data.dtypes
# Out:
# dtype('O')

# %%
new_time_data = pd.to_datetime(time_data)

# %%
new_time_data.dtypes
# Out:
# dtype('<M8[ns]')

# %%
print(new_time_data)
# Out:
# 0    2022-08-26
# 1    2022-08-27
# 2    2022-08-28
# 3    2022-08-29
# 4    2022-08-30
# 5    2022-08-31
# 6    2022-09-01
# 7    2022-09-02
# 8    2022-09-03
# 9    2022-09-04
# 10   2022-09-05
# 11   2022-09-06
# 12   2022-09-07
# 13   2022-09-08
# 14   2022-09-09
# 15   2022-09-10
# 16   2022-09-11
# 17   2022-09-12
# 18   2022-09-13
# 19   2022-09-14
# 20   2022-09-15
# 21   2022-09-16
# 22   2022-09-17
# 23   2022-09-18
# 24   2022-09-19
# 25   2022-09-20
# 26   2022-09-21
# 27   2022-08-26
# 28   2022-08-27
# 29   2022-08-28
# 30   2022-08-29
# 31   2022-08-30
# 32   2022-08-31
# 33   2022-09-01
# 34   2022-09-02
# 35   2022-09-03
# 36   2022-09-04
# 37   2022-09-05
# 38   2022-09-06
# 39   2022-09-07
# 40   2022-09-08
# 41   2022-09-09
# 42   2022-09-10
# 43   2022-09-11
# 44   2022-09-12
# 45   2022-09-13
# 46   2022-09-14
# 47   2022-09-15
# 48   2022-09-16
# 49   2022-09-17
# 50   2022-09-18
# 51   2022-09-19
# 52   2022-09-20
# 53   2022-09-21
# ...

# %%
new_time_data.dt.year.value_counts()
# Out:
# Date
# 2022    54
# Name: count, dtype: int64

# %%
new_time_data.dt.month.value_counts()
# Out:
# Date
# 9    42
# 8    12
# Name: count, dtype: int64

# %%
new_time_data.dt.day.value_counts()
# Out:
# Date
# 26    2
# 27    2
# 28    2
# 29    2
# 30    2
# 31    2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    2
# 19    2
# 20    2
# 21    2
# Name: count, dtype: int64

# %%
index_time_data = pd.date_range(
    start = '2023-01-01',
    end = '2023-01-10',
    freq = 'D'
)

# %%
new_time_data.head(5)
# Out:
# 0   2022-08-26
# 1   2022-08-27
# 2   2022-08-28
# 3   2022-08-29
# 4   2022-08-30
# Name: Date, dtype: datetime64[ns]

# %%
new_time_data.shape
# Out:
# (54,)

# %%
import random

demo_data = pd.DataFrame(
    {"values" : [random.randint(1, 100) for _ in range(54)]},
    index = new_time_data
)

# %%
demo_data
# Out:
#             values
# Date
# 2022-08-26      39
# 2022-08-27      16
# 2022-08-28      19
# 2022-08-29      25
# 2022-08-30      68
# 2022-08-31      84
# 2022-09-01      33
# 2022-09-02       6
# 2022-09-03      21
# 2022-09-04      29
# 2022-09-05      98
# 2022-09-06      91
# 2022-09-07      62
# 2022-09-08      95
# 2022-09-09      85
# 2022-09-10      96
# 2022-09-11       1
# 2022-09-12      79
# 2022-09-13      12
# 2022-09-14      80
# 2022-09-15       5
# 2022-09-16      97
# 2022-09-17      40
# 2022-09-18      68
# 2022-09-19      43
# 2022-09-20       2
# 2022-09-21      75
# 2022-08-26      53
# 2022-08-27      67
# 2022-08-28      69
# 2022-08-29      46
# 2022-08-30      26
# 2022-08-31      78
# 2022-09-01      73
# 2022-09-02      62
# 2022-09-03      97
# 2022-09-04      46
# 2022-09-05      10
# 2022-09-06      36
# 2022-09-07      63
# 2022-09-08      11
# 2022-09-09      53
# 2022-09-10       5
# 2022-09-11       6
# 2022-09-12      11
# 2022-09-13      94
# ...

# %%
demo_data.loc['2022-08-26']
# Out:
#             values
# Date
# 2022-08-26      39
# 2022-08-26      53

# %%
demo_data.loc["2022-08-26" : "2022-08-31"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 demo_data.loc["2022-08-26" : "2022-08-31"]
#
# File c:\Users\hi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\hi\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1412, in _LocIndexer._getitem_axis(self, key, axis)
#    1410 if isinstance(key, slice):
#    1411     self._validate_key(key, axis)
# -> 1412     return self._get_slice_axis(key, axis=axis)
#    1413 elif com.is_bool_indexer(key):
#    1414     return self._getbool_axis(key, axis=axis)
#
# ...

# %%
full_dates = pd.date_range(data['Date'].min (), data['Date'].max())

# %%
print(full_dates)
# Out:
# DatetimeIndex(['2022-08-26', '2022-08-27', '2022-08-28', '2022-08-29',
#                '2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02',
#                '2022-09-03', '2022-09-04', '2022-09-05', '2022-09-06',
#                '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-10',
#                '2022-09-11', '2022-09-12', '2022-09-13', '2022-09-14',
#                '2022-09-15', '2022-09-16', '2022-09-17', '2022-09-18',
#                '2022-09-19', '2022-09-20', '2022-09-21'],
#               dtype='datetime64[ns]', freq='D')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data = data.set_index(data['Date'])

# %%
data.drop('Date', axis = 1, inplace = True)

# %%
data.head()
# Out:
#             Usage  Notifications  Times opened        App
# Date
# 2022-08-26     38             70            49  Instagram
# 2022-08-27     39             43            48  Instagram
# 2022-08-28     64            231            55  Instagram
# 2022-08-29     14             35            23  Instagram
# 2022-08-30      3             19             5  Instagram

# %%
data.index.min()
# Out:
# Timestamp('2022-08-26 00:00:00')

# %%
data.index.max()
# Out:
# Timestamp('2022-09-21 00:00:00')

# %%
data.index.to_series().median()
# Out:
# Timestamp('2022-09-08 00:00:00')

# %%
data.index.to_series().quantile(0.7)
# Out:
# Timestamp('2022-09-13 02:24:00')

# %%
print(data.index)
# Out:
# DatetimeIndex(['2022-08-26', '2022-08-27', '2022-08-28', '2022-08-29',
#                '2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02',
#                '2022-09-03', '2022-09-04', '2022-09-05', '2022-09-06',
#                '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-10',
#                '2022-09-11', '2022-09-12', '2022-09-13', '2022-09-14',
#                '2022-09-15', '2022-09-16', '2022-09-17', '2022-09-18',
#                '2022-09-19', '2022-09-20', '2022-09-21', '2022-08-26',
#                '2022-08-27', '2022-08-28', '2022-08-29', '2022-08-30',
#                '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-03',
#                '2022-09-04', '2022-09-05', '2022-09-06', '2022-09-07',
#                '2022-09-08', '2022-09-09', '2022-09-10', '2022-09-11',
#                '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15',
#                '2022-09-16', '2022-09-17', '2022-09-18', '2022-09-19',
#                '2022-09-20', '2022-09-21'],
# ...

# %%
data['lag_1'] = data['Usage'].shift(1)

# %%
data['rolling'] = data['Usage'].rolling(7).mean()

# %%
print(data)
# Out:
#             Usage  Notifications  Times opened        App  lag_1     rolling
# Date
# 2022-08-26     38             70            49  Instagram    NaN         NaN
# 2022-08-27     39             43            48  Instagram   38.0         NaN
# 2022-08-28     64            231            55  Instagram   39.0         NaN
# 2022-08-29     14             35            23  Instagram   64.0         NaN
# 2022-08-30      3             19             5  Instagram   14.0         NaN
# 2022-08-31     19             25            20  Instagram    3.0         NaN
# 2022-09-01     44             23            57  Instagram   19.0   31.571429
# 2022-09-02     16             28            22  Instagram   44.0   28.428571
# 2022-09-03     27             15            25  Instagram   16.0   26.714286
# 2022-09-04     72             29            30  Instagram   27.0   27.857143
# 2022-09-05     42             24            51  Instagram   72.0   31.857143
# ...

# %%
data.dropna(subset = ['lag_1', 'rolling'], inplace = True)

# %%
data
# Out:
#             Usage  Notifications  Times opened        App  lag_1     rolling
# Date
# 2022-09-01     44             23            57  Instagram   19.0   31.571429
# 2022-09-02     16             28            22  Instagram   44.0   28.428571
# 2022-09-03     27             15            25  Instagram   16.0   26.714286
# 2022-09-04     72             29            30  Instagram   27.0   27.857143
# 2022-09-05     42             24            51  Instagram   72.0   31.857143
# 2022-09-06     19             34            25  Instagram   42.0   34.142857
# 2022-09-07     38             23            19  Instagram   19.0   36.857143
# 2022-09-08     71             48            43  Instagram   38.0   40.714286
# 2022-09-09     43             68            70  Instagram   71.0   44.571429
# 2022-09-10     45             71            70  Instagram   43.0   47.142857
# 2022-09-11     94            180            95  Instagram   45.0   50.285714
# ...

# %%
data['App'].value_counts()
# Out:
# App
# Whatsapp     27
# Instagram    21
# Name: count, dtype: int64

# %%
dict = {
    'Whatsapp' : 1, 
    'Instagram' : 0
}

# %%
data['App'] = data['App'].map(dict)

# %%
X = data.drop('Notifications', axis = 1)

# %%
y = data['Notifications']

# %%
train_size = int(len(data)* 0.8)

# %%
X_train, X_test = X[: train_size], X[train_size:]

# %%
y_train, y_test = y[: train_size], y[train_size:]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators = 100)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 58.150999999999996

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)

# %%
r2
# Out:
# -1.4056317628387336

# %%
importance = model.feature_importances_
feature_names = X.columns
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importance
}).sort_values(by='Importance', ascending=False)
print(feature_importance_df)
# Out:
#         Feature  Importance
# 1  Times opened    0.791036
# 0         Usage    0.097879
# 2           App    0.045760
# 3         lag_1    0.036369
# 4       rolling    0.028956

# %%
# Điểm yếu của randomforestree là khi mà dataset có những cột mà trong mỗi cột có nhiều giá trị khác nhau
